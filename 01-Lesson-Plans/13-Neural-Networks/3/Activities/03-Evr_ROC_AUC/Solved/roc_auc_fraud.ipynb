# %% [markdown]
# # Instructor Do: Intro to the ROC Curve and AUC
#
# In this activity, students will learn how to measure the performance of a binary classification model by fetching metrics from Keras, as well as plotting and interpreting the ROC curve and AUC.

# %%
# Initial imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# ## The Dataset
#
# The data provided for this demo contains anonymous information about `284807` credit card transactions made by European credit cardholders in September 2013.
#
# The dataset is going to be used to create a binary classification model using a deep neural network to detect fraudulent transactions. It contains nine numerical variables, which are the result of PCA transformation to protect the confidentiality of credit cardholders. Only the transaction amount can be seen as is.
#
# This dataset is an abstract of the file shared by the [Machine Learning Group](http://mlg.ulb.ac.be) of the Université Libre de Bruxelles (ULB).

# %%
# Import the dataset
file_path = Path("../Resources/transactions.csv")
transactions_df = pd.read_csv(file_path)
transactions_df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  Amount  Class
# 0  0.098698  0.363787  149.62      0
# 1  0.085102 -0.255425    2.69      0
# 2  0.247676 -1.514654  378.66      0
# 3  0.377436 -1.387024  123.50      0
# 4 -0.270533  0.817739   69.99      0

# %% [markdown]
# ## Data Preprocessing

# %%
# Creating the X and y sets
X = transactions_df.iloc[:, 0:10].values
y = transactions_df["Class"].values

# %%
# Creating training, validation, and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, random_state=78)

# %%
# Import the StandardScaler from sklearn
from sklearn.preprocessing import StandardScaler

# Scale the data
scaler = StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)

# %% [markdown]
# ## Build and Train the Deep Learning Model

# %% [markdown]
#  ### Importing the Keras Modules

# %%
# Import Keras modules for model creation
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
#  ### Setting Up the Model

# %%
# Model set-up
number_input_features = 10
hidden_nodes_layer1 = 15
hidden_nodes_layer2 = 5

# %% [markdown]
#  ### Defining the Model's Structure

# %%
# Define the LSTM RNN model
model = Sequential()

# Layer 1
model.add(
    Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Layer 2
model.add(Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
model.add(Dense(1, activation="sigmoid"))

# %% [markdown]
#  ### Compiling the Model

# %%
# Compile the model
model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=[
        "accuracy",
        tf.keras.metrics.TruePositives(name="tp"),
        tf.keras.metrics.TrueNegatives(name="tn"),
        tf.keras.metrics.FalsePositives(name="fp"),
        tf.keras.metrics.FalseNegatives(name="fn"),
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall"),
        tf.keras.metrics.AUC(name="auc"),
    ],
)

# %%
# Summarize the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 15)                165
#
#  dense_1 (Dense)             (None, 5)                 80
#
#  dense_2 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 251
# Trainable params: 251
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
#  ### Training the Model

# %%
# Training the model
batch_size = 1000
epochs = 50
training_history = model.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),
    epochs=epochs,
    batch_size=batch_size,
    verbose=1,
)
# Out:
# Epoch 1/50
# 161/161 [==============================] - 2s 5ms/step - loss: 0.4144 - accuracy: 0.9422 - tp: 22.0000 - tn: 150929.0000 - fp: 9017.0000 - fn: 235.0000 - precision: 0.0024 - recall: 0.0856 - auc: 0.2711 - val_loss: 0.1218 - val_accuracy: 0.9980 - val_tp: 0.0000e+00 - val_tn: 53297.0000 - val_fp: 0.0000e+00 - val_fn: 105.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.3880
# Epoch 2/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0689 - accuracy: 0.9984 - tp: 0.0000e+00 - tn: 159946.0000 - fp: 0.0000e+00 - fn: 257.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.1780 - val_loss: 0.1379 - val_accuracy: 0.9980 - val_tp: 0.0000e+00 - val_tn: 53297.0000 - val_fp: 0.0000e+00 - val_fn: 105.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4697
# Epoch 3/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0216 - accuracy: 0.9984 - tp: 0.0000e+00 - tn: 159946.0000 - fp: 0.0000e+00 - fn: 257.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5528 - val_loss: 0.1489 - val_accuracy: 0.9980 - val_tp: 0.0000e+00 - val_tn: 53297.0000 - val_fp: 0.0000e+00 - val_fn: 105.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5853
# Epoch 4/50
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0123 - accuracy: 0.9984 - tp: 0.0000e+00 - tn: 159946.0000 - fp: 0.0000e+00 - fn: 257.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.7745 - val_loss: 0.1545 - val_accuracy: 0.9980 - val_tp: 0.0000e+00 - val_tn: 53297.0000 - val_fp: 0.0000e+00 - val_fn: 105.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6364
# Epoch 5/50
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0093 - accuracy: 0.9984 - tp: 0.0000e+00 - tn: 159946.0000 - fp: 0.0000e+00 - fn: 257.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.8226 - val_loss: 0.1544 - val_accuracy: 0.9980 - val_tp: 0.0000e+00 - val_tn: 53297.0000 - val_fp: 0.0000e+00 - val_fn: 105.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6562
# Epoch 6/50
# 161/161 [==============================] - 1s 4ms/step - loss: 0.0079 - accuracy: 0.9984 - tp: 0.0000e+00 - tn: 159946.0000 - fp: 0.0000e+00 - fn: 257.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.8391 - val_loss: 0.1498 - val_accuracy: 0.9981 - val_tp: 4.0000 - val_tn: 53297.0000 - val_fp: 0.0000e+00 - val_fn: 101.0000 - val_precision: 1.0000 - val_recall: 0.0381 - val_auc: 0.6798
# Epoch 7/50
# 161/161 [==============================] - 1s 3ms/step - loss: 0.0071 - accuracy: 0.9985 - tp: 12.0000 - tn: 159944.0000 - fp: 2.0000 - fn: 245.0000 - precision: 0.8571 - recall: 0.0467 - auc: 0.8534 - val_loss: 0.1423 - val_accuracy: 0.9983 - val_tp: 14.0000 - val_tn: 53296.0000 - val_fp: 1.0000 - val_fn: 91.0000 - val_precision: 0.9333 - val_recall: 0.1333 - val_auc: 0.6916
# Epoch 8/50
# 161/161 [==============================] - 1s 4ms/step - loss: 0.0065 - accuracy: 0.9987 - tp: 53.0000 - tn: 159937.0000 - fp: 9.0000 - fn: 204.0000 - precision: 0.8548 - recall: 0.2062 - auc: 0.8677 - val_loss: 0.1294 - val_accuracy: 0.9983 - val_tp: 19.0000 - val_tn: 53293.0000 - val_fp: 4.0000 - val_fn: 86.0000 - val_precision: 0.8261 - val_recall: 0.1810 - val_auc: 0.6919
# Epoch 9/50
# 161/161 [==============================] - 1s 4ms/step - loss: 0.0060 - accuracy: 0.9988 - tp: 75.0000 - tn: 159931.0000 - fp: 15.0000 - fn: 182.0000 - precision: 0.8333 - recall: 0.2918 - auc: 0.8849 - val_loss: 0.1177 - val_accuracy: 0.9984 - val_tp: 28.0000 - val_tn: 53289.0000 - val_fp: 8.0000 - val_fn: 77.0000 - val_precision: 0.7778 - val_recall: 0.2667 - val_auc: 0.7057
# Epoch 10/50
# 161/161 [==============================] - 1s 4ms/step - loss: 0.0056 - accuracy: 0.9989 - tp: 107.0000 - tn: 159926.0000 - fp: 20.0000 - fn: 150.0000 - precision: 0.8425 - recall: 0.4163 - auc: 0.8918 - val_loss: 0.1090 - val_accuracy: 0.9984 - val_tp: 31.0000 - val_tn: 53286.0000 - val_fp: 11.0000 - val_fn: 74.0000 - val_precision: 0.7381 - val_recall: 0.2952 - val_auc: 0.7246
# Epoch 11/50
# 161/161 [==============================] - 1s 3ms/step - loss: 0.0052 - accuracy: 0.9990 - tp: 124.0000 - tn: 159926.0000 - fp: 20.0000 - fn: 133.0000 - precision: 0.8611 - recall: 0.4825 - auc: 0.8910 - val_loss: 0.0965 - val_accuracy: 0.9983 - val_tp: 37.0000 - val_tn: 53275.0000 - val_fp: 22.0000 - val_fn: 68.0000 - val_precision: 0.6271 - val_recall: 0.3524 - val_auc: 0.7426
# Epoch 12/50
# 161/161 [==============================] - 1s 3ms/step - loss: 0.0049 - accuracy: 0.9991 - tp: 134.0000 - tn: 159924.0000 - fp: 22.0000 - fn: 123.0000 - precision: 0.8590 - recall: 0.5214 - auc: 0.8991 - val_loss: 0.0879 - val_accuracy: 0.9982 - val_tp: 40.0000 - val_tn: 53268.0000 - val_fp: 29.0000 - val_fn: 65.0000 - val_precision: 0.5797 - val_recall: 0.3810 - val_auc: 0.7429
# Epoch 13/50
# 161/161 [==============================] - 1s 3ms/step - loss: 0.0047 - accuracy: 0.9991 - tp: 141.0000 - tn: 159923.0000 - fp: 23.0000 - fn: 116.0000 - precision: 0.8598 - recall: 0.5486 - auc: 0.8995 - val_loss: 0.0782 - val_accuracy: 0.9981 - val_tp: 41.0000 - val_tn: 53258.0000 - val_fp: 39.0000 - val_fn: 64.0000 - val_precision: 0.5125 - val_recall: 0.3905 - val_auc: 0.7557
# Epoch 14/50
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 0.9992 - tp: 145.0000 - tn: 159924.0000 - fp: 22.0000 - fn: 112.0000 - precision: 0.8683 - recall: 0.5642 - auc: 0.9036 - val_loss: 0.0737 - val_accuracy: 0.9978 - val_tp: 43.0000 - val_tn: 53243.0000 - val_fp: 54.0000 - val_fn: 62.0000 - val_precision: 0.4433 - val_recall: 0.4095 - val_auc: 0.7650
# Epoch 15/50
# 161/161 [==============================] - 1s 4ms/step - loss: 0.0044 - accuracy: 0.9992 - tp: 144.0000 - tn: 159923.0000 - fp: 23.0000 - fn: 113.0000 - precision: 0.8623 - recall: 0.5603 - auc: 0.9039 - val_loss: 0.0676 - val_accuracy: 0.9975 - val_tp: 47.0000 - val_tn: 53224.0000 - val_fp: 73.0000 - val_fn: 58.0000 - val_precision: 0.3917 - val_recall: 0.4476 - val_auc: 0.7725
# Epoch 16/50
# 161/161 [==============================] - 1s 3ms/step - loss: 0.0043 - accuracy: 0.9992 - tp: 152.0000 - tn: 159922.0000 - fp: 24.0000 - fn: 105.0000 - precision: 0.8636 - recall: 0.5914 - auc: 0.9098 - val_loss: 0.0689 - val_accuracy: 0.9975 - val_tp: 48.0000 - val_tn: 53223.0000 - val_fp: 74.0000 - val_fn: 57.0000 - val_precision: 0.3934 - val_recall: 0.4571 - val_auc: 0.7744
# Epoch 17/50
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0042 - accuracy: 0.9992 - tp: 155.0000 - tn: 159922.0000 - fp: 24.0000 - fn: 102.0000 - precision: 0.8659 - recall: 0.6031 - auc: 0.9137 - val_loss: 0.0661 - val_accuracy: 0.9975 - val_tp: 49.0000 - val_tn: 53219.0000 - val_fp: 78.0000 - val_fn: 56.0000 - val_precision: 0.3858 - val_recall: 0.4667 - val_auc: 0.7742
# Epoch 18/50
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 0.9992 - tp: 152.0000 - tn: 159922.0000 - fp: 24.0000 - fn: 105.0000 - precision: 0.8636 - recall: 0.5914 - auc: 0.9102 - val_loss: 0.0632 - val_accuracy: 0.9972 - val_tp: 49.0000 - val_tn: 53204.0000 - val_fp: 93.0000 - val_fn: 56.0000 - val_precision: 0.3451 - val_recall: 0.4667 - val_auc: 0.7727
# Epoch 19/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0041 - accuracy: 0.9992 - tp: 159.0000 - tn: 159922.0000 - fp: 24.0000 - fn: 98.0000 - precision: 0.8689 - recall: 0.6187 - auc: 0.9160 - val_loss: 0.0613 - val_accuracy: 0.9973 - val_tp: 48.0000 - val_tn: 53210.0000 - val_fp: 87.0000 - val_fn: 57.0000 - val_precision: 0.3556 - val_recall: 0.4571 - val_auc: 0.7770
# Epoch 20/50
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 0.9993 - tp: 159.0000 - tn: 159924.0000 - fp: 22.0000 - fn: 98.0000 - precision: 0.8785 - recall: 0.6187 - auc: 0.9103 - val_loss: 0.0640 - val_accuracy: 0.9975 - val_tp: 48.0000 - val_tn: 53219.0000 - val_fp: 78.0000 - val_fn: 57.0000 - val_precision: 0.3810 - val_recall: 0.4571 - val_auc: 0.7744
# Epoch 21/50
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 0.9992 - tp: 156.0000 - tn: 159925.0000 - fp: 21.0000 - fn: 101.0000 - precision: 0.8814 - recall: 0.6070 - auc: 0.9143 - val_loss: 0.0568 - val_accuracy: 0.9967 - val_tp: 50.0000 - val_tn: 53178.0000 - val_fp: 119.0000 - val_fn: 55.0000 - val_precision: 0.2959 - val_recall: 0.4762 - val_auc: 0.7883
# Epoch 22/50
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 0.9992 - tp: 156.0000 - tn: 159923.0000 - fp: 23.0000 - fn: 101.0000 - precision: 0.8715 - recall: 0.6070 - auc: 0.9162 - val_loss: 0.0551 - val_accuracy: 0.9966 - val_tp: 51.0000 - val_tn: 53169.0000 - val_fp: 128.0000 - val_fn: 54.0000 - val_precision: 0.2849 - val_recall: 0.4857 - val_auc: 0.8011
# Epoch 23/50
# 161/161 [==============================] - 1s 4ms/step - loss: 0.0039 - accuracy: 0.9992 - tp: 159.0000 - tn: 159922.0000 - fp: 24.0000 - fn: 98.0000 - precision: 0.8689 - recall: 0.6187 - auc: 0.9144 - val_loss: 0.0528 - val_accuracy: 0.9967 - val_tp: 51.0000 - val_tn: 53173.0000 - val_fp: 124.0000 - val_fn: 54.0000 - val_precision: 0.2914 - val_recall: 0.4857 - val_auc: 0.8059
# Epoch 24/50
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 0.9992 - tp: 157.0000 - tn: 159923.0000 - fp: 23.0000 - fn: 100.0000 - precision: 0.8722 - recall: 0.6109 - auc: 0.9182 - val_loss: 0.0504 - val_accuracy: 0.9962 - val_tp: 52.0000 - val_tn: 53149.0000 - val_fp: 148.0000 - val_fn: 53.0000 - val_precision: 0.2600 - val_recall: 0.4952 - val_auc: 0.8152
# Epoch 25/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0038 - accuracy: 0.9993 - tp: 162.0000 - tn: 159925.0000 - fp: 21.0000 - fn: 95.0000 - precision: 0.8852 - recall: 0.6304 - auc: 0.9221 - val_loss: 0.0482 - val_accuracy: 0.9960 - val_tp: 52.0000 - val_tn: 53138.0000 - val_fp: 159.0000 - val_fn: 53.0000 - val_precision: 0.2464 - val_recall: 0.4952 - val_auc: 0.8205
# Epoch 26/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0038 - accuracy: 0.9993 - tp: 164.0000 - tn: 159923.0000 - fp: 23.0000 - fn: 93.0000 - precision: 0.8770 - recall: 0.6381 - auc: 0.9222 - val_loss: 0.0479 - val_accuracy: 0.9963 - val_tp: 52.0000 - val_tn: 53154.0000 - val_fp: 143.0000 - val_fn: 53.0000 - val_precision: 0.2667 - val_recall: 0.4952 - val_auc: 0.8257
# Epoch 27/50
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 0.9993 - tp: 160.0000 - tn: 159925.0000 - fp: 21.0000 - fn: 97.0000 - precision: 0.8840 - recall: 0.6226 - auc: 0.9261 - val_loss: 0.0468 - val_accuracy: 0.9961 - val_tp: 52.0000 - val_tn: 53140.0000 - val_fp: 157.0000 - val_fn: 53.0000 - val_precision: 0.2488 - val_recall: 0.4952 - val_auc: 0.8306
# Epoch 28/50
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 0.9993 - tp: 165.0000 - tn: 159924.0000 - fp: 22.0000 - fn: 92.0000 - precision: 0.8824 - recall: 0.6420 - auc: 0.9242 - val_loss: 0.0453 - val_accuracy: 0.9959 - val_tp: 54.0000 - val_tn: 53130.0000 - val_fp: 167.0000 - val_fn: 51.0000 - val_precision: 0.2443 - val_recall: 0.5143 - val_auc: 0.8303
# Epoch 29/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0037 - accuracy: 0.9993 - tp: 165.0000 - tn: 159926.0000 - fp: 20.0000 - fn: 92.0000 - precision: 0.8919 - recall: 0.6420 - auc: 0.9262 - val_loss: 0.0440 - val_accuracy: 0.9956 - val_tp: 57.0000 - val_tn: 53108.0000 - val_fp: 189.0000 - val_fn: 48.0000 - val_precision: 0.2317 - val_recall: 0.5429 - val_auc: 0.8338
# Epoch 30/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0037 - accuracy: 0.9993 - tp: 160.0000 - tn: 159925.0000 - fp: 21.0000 - fn: 97.0000 - precision: 0.8840 - recall: 0.6226 - auc: 0.9262 - val_loss: 0.0431 - val_accuracy: 0.9955 - val_tp: 57.0000 - val_tn: 53104.0000 - val_fp: 193.0000 - val_fn: 48.0000 - val_precision: 0.2280 - val_recall: 0.5429 - val_auc: 0.8423
# Epoch 31/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0036 - accuracy: 0.9993 - tp: 165.0000 - tn: 159924.0000 - fp: 22.0000 - fn: 92.0000 - precision: 0.8824 - recall: 0.6420 - auc: 0.9263 - val_loss: 0.0411 - val_accuracy: 0.9955 - val_tp: 57.0000 - val_tn: 53106.0000 - val_fp: 191.0000 - val_fn: 48.0000 - val_precision: 0.2298 - val_recall: 0.5429 - val_auc: 0.8468
# Epoch 32/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0036 - accuracy: 0.9993 - tp: 162.0000 - tn: 159926.0000 - fp: 20.0000 - fn: 95.0000 - precision: 0.8901 - recall: 0.6304 - auc: 0.9263 - val_loss: 0.0405 - val_accuracy: 0.9955 - val_tp: 59.0000 - val_tn: 53102.0000 - val_fp: 195.0000 - val_fn: 46.0000 - val_precision: 0.2323 - val_recall: 0.5619 - val_auc: 0.8478
# Epoch 33/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0036 - accuracy: 0.9993 - tp: 163.0000 - tn: 159926.0000 - fp: 20.0000 - fn: 94.0000 - precision: 0.8907 - recall: 0.6342 - auc: 0.9262 - val_loss: 0.0405 - val_accuracy: 0.9957 - val_tp: 59.0000 - val_tn: 53113.0000 - val_fp: 184.0000 - val_fn: 46.0000 - val_precision: 0.2428 - val_recall: 0.5619 - val_auc: 0.8491
# Epoch 34/50
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 0.9993 - tp: 163.0000 - tn: 159926.0000 - fp: 20.0000 - fn: 94.0000 - precision: 0.8907 - recall: 0.6342 - auc: 0.9245 - val_loss: 0.0389 - val_accuracy: 0.9951 - val_tp: 61.0000 - val_tn: 53078.0000 - val_fp: 219.0000 - val_fn: 44.0000 - val_precision: 0.2179 - val_recall: 0.5810 - val_auc: 0.8472
# Epoch 35/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0036 - accuracy: 0.9993 - tp: 163.0000 - tn: 159925.0000 - fp: 21.0000 - fn: 94.0000 - precision: 0.8859 - recall: 0.6342 - auc: 0.9264 - val_loss: 0.0382 - val_accuracy: 0.9954 - val_tp: 61.0000 - val_tn: 53094.0000 - val_fp: 203.0000 - val_fn: 44.0000 - val_precision: 0.2311 - val_recall: 0.5810 - val_auc: 0.8478
# Epoch 36/50
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 0.9993 - tp: 165.0000 - tn: 159926.0000 - fp: 20.0000 - fn: 92.0000 - precision: 0.8919 - recall: 0.6420 - auc: 0.9245 - val_loss: 0.0395 - val_accuracy: 0.9950 - val_tp: 62.0000 - val_tn: 53073.0000 - val_fp: 224.0000 - val_fn: 43.0000 - val_precision: 0.2168 - val_recall: 0.5905 - val_auc: 0.8486
# Epoch 37/50
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 0.9993 - tp: 169.0000 - tn: 159925.0000 - fp: 21.0000 - fn: 88.0000 - precision: 0.8895 - recall: 0.6576 - auc: 0.9283 - val_loss: 0.0361 - val_accuracy: 0.9946 - val_tp: 63.0000 - val_tn: 53049.0000 - val_fp: 248.0000 - val_fn: 42.0000 - val_precision: 0.2026 - val_recall: 0.6000 - val_auc: 0.8481
# Epoch 38/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0035 - accuracy: 0.9993 - tp: 164.0000 - tn: 159925.0000 - fp: 21.0000 - fn: 93.0000 - precision: 0.8865 - recall: 0.6381 - auc: 0.9264 - val_loss: 0.0374 - val_accuracy: 0.9940 - val_tp: 64.0000 - val_tn: 53020.0000 - val_fp: 277.0000 - val_fn: 41.0000 - val_precision: 0.1877 - val_recall: 0.6095 - val_auc: 0.8495
# Epoch 39/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0035 - accuracy: 0.9993 - tp: 167.0000 - tn: 159926.0000 - fp: 20.0000 - fn: 90.0000 - precision: 0.8930 - recall: 0.6498 - auc: 0.9264 - val_loss: 0.0350 - val_accuracy: 0.9950 - val_tp: 61.0000 - val_tn: 53076.0000 - val_fp: 221.0000 - val_fn: 44.0000 - val_precision: 0.2163 - val_recall: 0.5810 - val_auc: 0.8474
# Epoch 40/50
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 0.9993 - tp: 169.0000 - tn: 159924.0000 - fp: 22.0000 - fn: 88.0000 - precision: 0.8848 - recall: 0.6576 - auc: 0.9284 - val_loss: 0.0352 - val_accuracy: 0.9946 - val_tp: 63.0000 - val_tn: 53050.0000 - val_fp: 247.0000 - val_fn: 42.0000 - val_precision: 0.2032 - val_recall: 0.6000 - val_auc: 0.8538
# Epoch 41/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0035 - accuracy: 0.9993 - tp: 165.0000 - tn: 159926.0000 - fp: 20.0000 - fn: 92.0000 - precision: 0.8919 - recall: 0.6420 - auc: 0.9284 - val_loss: 0.0353 - val_accuracy: 0.9944 - val_tp: 63.0000 - val_tn: 53038.0000 - val_fp: 259.0000 - val_fn: 42.0000 - val_precision: 0.1957 - val_recall: 0.6000 - val_auc: 0.8546
# Epoch 42/50
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 0.9993 - tp: 167.0000 - tn: 159923.0000 - fp: 23.0000 - fn: 90.0000 - precision: 0.8789 - recall: 0.6498 - auc: 0.9284 - val_loss: 0.0360 - val_accuracy: 0.9940 - val_tp: 67.0000 - val_tn: 53014.0000 - val_fp: 283.0000 - val_fn: 38.0000 - val_precision: 0.1914 - val_recall: 0.6381 - val_auc: 0.8538
# Epoch 43/50
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0034 - accuracy: 0.9993 - tp: 170.0000 - tn: 159925.0000 - fp: 21.0000 - fn: 87.0000 - precision: 0.8901 - recall: 0.6615 - auc: 0.9285 - val_loss: 0.0327 - val_accuracy: 0.9947 - val_tp: 65.0000 - val_tn: 53053.0000 - val_fp: 244.0000 - val_fn: 40.0000 - val_precision: 0.2104 - val_recall: 0.6190 - val_auc: 0.8532
# Epoch 44/50
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 0.9993 - tp: 166.0000 - tn: 159926.0000 - fp: 20.0000 - fn: 91.0000 - precision: 0.8925 - recall: 0.6459 - auc: 0.9322 - val_loss: 0.0335 - val_accuracy: 0.9949 - val_tp: 64.0000 - val_tn: 53063.0000 - val_fp: 234.0000 - val_fn: 41.0000 - val_precision: 0.2148 - val_recall: 0.6095 - val_auc: 0.8535
# Epoch 45/50
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9994 - tp: 173.0000 - tn: 159926.0000 - fp: 20.0000 - fn: 84.0000 - precision: 0.8964 - recall: 0.6732 - auc: 0.9285 - val_loss: 0.0323 - val_accuracy: 0.9957 - val_tp: 61.0000 - val_tn: 53114.0000 - val_fp: 183.0000 - val_fn: 44.0000 - val_precision: 0.2500 - val_recall: 0.5810 - val_auc: 0.8551
# Epoch 46/50
# 161/161 [==============================] - 1s 4ms/step - loss: 0.0034 - accuracy: 0.9993 - tp: 168.0000 - tn: 159927.0000 - fp: 19.0000 - fn: 89.0000 - precision: 0.8984 - recall: 0.6537 - auc: 0.9304 - val_loss: 0.0361 - val_accuracy: 0.9933 - val_tp: 67.0000 - val_tn: 52979.0000 - val_fp: 318.0000 - val_fn: 38.0000 - val_precision: 0.1740 - val_recall: 0.6381 - val_auc: 0.8651
# Epoch 47/50
# 161/161 [==============================] - 1s 3ms/step - loss: 0.0034 - accuracy: 0.9993 - tp: 175.0000 - tn: 159922.0000 - fp: 24.0000 - fn: 82.0000 - precision: 0.8794 - recall: 0.6809 - auc: 0.9323 - val_loss: 0.0325 - val_accuracy: 0.9957 - val_tp: 63.0000 - val_tn: 53107.0000 - val_fp: 190.0000 - val_fn: 42.0000 - val_precision: 0.2490 - val_recall: 0.6000 - val_auc: 0.8549
# Epoch 48/50
# 161/161 [==============================] - 1s 4ms/step - loss: 0.0034 - accuracy: 0.9993 - tp: 171.0000 - tn: 159925.0000 - fp: 21.0000 - fn: 86.0000 - precision: 0.8906 - recall: 0.6654 - auc: 0.9361 - val_loss: 0.0330 - val_accuracy: 0.9964 - val_tp: 60.0000 - val_tn: 53149.0000 - val_fp: 148.0000 - val_fn: 45.0000 - val_precision: 0.2885 - val_recall: 0.5714 - val_auc: 0.8563
# Epoch 49/50
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9993 - tp: 170.0000 - tn: 159924.0000 - fp: 22.0000 - fn: 87.0000 - precision: 0.8854 - recall: 0.6615 - auc: 0.9324 - val_loss: 0.0326 - val_accuracy: 0.9955 - val_tp: 63.0000 - val_tn: 53101.0000 - val_fp: 196.0000 - val_fn: 42.0000 - val_precision: 0.2432 - val_recall: 0.6000 - val_auc: 0.8543
# Epoch 50/50
# 161/161 [==============================] - 1s 4ms/step - loss: 0.0034 - accuracy: 0.9994 - tp: 172.0000 - tn: 159927.0000 - fp: 19.0000 - fn: 85.0000 - precision: 0.9005 - recall: 0.6693 - auc: 0.9362 - val_loss: 0.0314 - val_accuracy: 0.9956 - val_tp: 65.0000 - val_tn: 53101.0000 - val_fp: 196.0000 - val_fn: 40.0000 - val_precision: 0.2490 - val_recall: 0.6190 - val_auc: 0.8550

# %% [markdown]
# ### Model Performance

# %% [markdown]
# #### Checking Training History

# %%
# Plotting loss
loss_df = pd.DataFrame(
    {
        "Epoch": range(1, epochs + 1),
        "Train": training_history.history["loss"],
        "Val": training_history.history["val_loss"],
    }
)
loss_df.set_index("Epoch", inplace=True)
loss_df.plot(title="Loss")
# Out:
# <AxesSubplot: title={'center': 'Loss'}, xlabel='Epoch'>

# %%
# Plotting accuracy
accuracy_df = pd.DataFrame(
    {
        "Epoch": range(1, epochs + 1),
        "Train": training_history.history["accuracy"],
        "Val": training_history.history["val_accuracy"],
    }
)
accuracy_df.set_index("Epoch", inplace=True)
accuracy_df.plot(title="Accuracy")
# Out:
# <AxesSubplot: title={'center': 'Accuracy'}, xlabel='Epoch'>

# %%
# Plotting AUC
auc_df = pd.DataFrame(
    {
        "Epoch": range(1, epochs + 1),
        "Train": training_history.history["auc"],
        "Val": training_history.history["val_auc"],
    }
)
auc_df.set_index("Epoch", inplace=True)
auc_df.plot(title="AUC")
# Out:
# <AxesSubplot: title={'center': 'AUC'}, xlabel='Epoch'>

# %% [markdown]
# #### Plotting the ROC Curve

# %%
# Import the roc_curve and auc metrics from sklearn
from sklearn.metrics import roc_curve, auc

# %%
# Making predictions to feed the roc_curve module
train_predictions = model.predict(X_train, batch_size=1000)
test_predictions = model.predict(X_test, batch_size=1000)
# Out:
# 161/161 [==============================] - 0s 1ms/step
# 72/72 [==============================] - 0s 983us/step

# %%
# Calculate the ROC curve and AUC for the training set
fpr_train, tpr_train, thresholds_train = roc_curve(y_train, train_predictions)
auc_train = auc(fpr_train, tpr_train)
auc_train = round(auc_train, 4)

# Calculate the ROC curve and AUC for the testing set
fpr_test, tpr_test, thresholds_test = roc_curve(y_test, test_predictions)
auc_test = auc(fpr_test, tpr_test)
auc_test = round(auc_test, 4)

# %%
# Create a DataFrame with the fpr and tpr results
roc_df_train = pd.DataFrame({"FPR Train": fpr_train, "TPR Train": tpr_train,})

roc_df_test = pd.DataFrame({"FPR Test": fpr_test, "TPR Test": tpr_test,})

# %%
# Plotting the ROC Curves
roc_df_train.plot(
    x="FPR Train",
    y="TPR Train",
    xlim=([-0.05, 1.05]),
    title=f"Train ROC Curve (AUC={auc_train})",
)

roc_df_test.plot(
    x="FPR Test",
    y="TPR Test",
    color="red",
    style="--",
    xlim=([-0.05, 1.05]),
    title=f"Test ROC Curve (AUC={auc_test})",
)
# Out:
# <AxesSubplot: title={'center': 'Test ROC Curve (AUC=0.8296)'}, xlabel='FPR Test'>

# %% [markdown]
# #### Evaluate the Model

# %%
# Evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)

# Define metrics dictionary
metrics = {k: v for k, v in zip(model.metrics_names, scores)}

# Display evaluation metrics results
display(metrics)
# Out:
# {'loss': 0.03151727467775345,
#  'accuracy': 0.995927095413208,
#  'tp': 76.0,
#  'tn': 70836.0,
#  'fp': 236.0,
#  'fn': 54.0,
#  'precision': 0.24358974397182465,
#  'recall': 0.5846154093742371,
#  'auc': 0.86839359998703}

# %% [markdown]
# #### Confusion Matrix

# %%
# Define the confusion matrix data
cm_df = pd.DataFrame(
    {
        "Positive (1)": [f"TP={metrics['tp']}", f"FP={metrics['fn']}"],
        "Negative (0)": [f"FN={metrics['fp']}", f"TN={metrics['tn']}"],
    },
    index=["Positive(1)", "Negative(0)"],
)
cm_df.index.name = "Actual"
cm_df.columns.name = "Predicted"

# Show the confusion matrix
cm_df
# Out:
# Predicted   Positive (1) Negative (0)
# Actual
# Positive(1)      TP=76.0     FN=236.0
# Negative(0)      FP=54.0   TN=70836.0

# %% [markdown]
# #### Classification Report

# %%
# Import the classification_report method from sklearn
from sklearn.metrics import classification_report

# Predict classes using testing data
y_predict_classes = (model.predict(X_test) > 0.5).astype("int32")

# Display classification report
print(classification_report(y_predict_classes, y_test))
# Out:
# 2226/2226 [==============================] - 3s 1ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     70890
#            1       0.58      0.24      0.34       312
#
#     accuracy                           1.00     71202
#    macro avg       0.79      0.62      0.67     71202
# weighted avg       0.99      1.00      1.00     71202
